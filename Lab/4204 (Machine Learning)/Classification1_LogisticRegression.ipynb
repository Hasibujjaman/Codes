# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
df = pd.read_csv('Heart_Disease_Prediction.csv')
df.head()

df = df[['Age', 'BP', 'Heart Disease']]
df.head()

X = df[['Age', 'BP']]
y = df['Heart Disease']

# %%
lr = LogisticRegression()
lr.fit(X, y)
y_pred = lr.predict(X)

# %%
confusion_matrix(y, y_pred)
# Out:
# array([[108,  42],
#        [ 68,  52]])

# %%
print(classification_report(y, y_pred, target_names=['Presence', 'Absence']))
# Out:
#               precision    recall  f1-score   support
#
#     Presence       0.61      0.72      0.66       150
#      Absence       0.55      0.43      0.49       120
#
#     accuracy                           0.59       270
#    macro avg       0.58      0.58      0.57       270
# weighted avg       0.59      0.59      0.58       270

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# heatmap of confusion matrix
cm = confusion_matrix(y, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Presence', 'Absence'], yticklabels=['Presence', 'Absence'])
plt.ylabel('Actual')
plt.xlabel('Predicted') 
plt.plot()
# Out:
# []
