# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
import pandas as pd

# %%
df = pd.read_csv('/Users/emonchowdhury/My Drive (emonahamed789@gmail.com)/Codes/Lab/4204 (Machine Learning)/Titanic-Dataset.csv')

# %%
profile = ProfileReport(df, title="Titanic Profiling Report").to_file("titanic_eda_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
